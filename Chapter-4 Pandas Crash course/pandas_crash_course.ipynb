# %% [markdown]
# # Chapter - 1
# ## Getting and Knowing your Data

# %%
import pandas as pd

# %%
pd.read_csv(filepath_or_buffer = "data.tsv.txt", sep = "\t") # this is the method to open tab seperated values in read_csv function
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.read_table(filepath_or_buffer = "output_with_timeline.csv", sep = ",") # this is the method to open comma seperated values in read_table function
# Out:
#      Start_Time  End_Time                                   PROGRAM/AD/SONGS  \
# 0      05:00:00  05:01:11                                    NO AUDIO PLAYED
# 1      05:01:11  05:02:05                    JINGLE: RADIO CITY 91.1 FM SONG
# 2      05:02:05  05:02:11  JINGLE: SRI VENKATESHWARA SUPRABHATHAM SONG INTRO
# 3      05:02:11  05:22:43  SONG: SRI VENKATESHWARA SUPRABATHAM, MS SUBBUL...
# 4      05:22:43  05:23:54             PROGRAM: AALAYA DHARISANAM, RJ SHAKTHI
# ...         ...       ...                                                ...
# 1372   23:53:46  23:54:05                                 JINGLE: RADIO CITY
# 1373   23:54:05  23:54:33                     JINGLE: DESAANDHIRI SONG INTRO
# 1374   23:54:33  23:57:42  SONG: DESAANDHIRI, SIDDHARTH & SANTHOSH NARAYA...
# 1375   23:57:42  23:58:00                                 JINGLE: RADIO CITY
# 1376   23:58:00  23:59:59  SONG: PATTUKUTTY, YUVAN SHANKAR RAJA, RAJA RAN...
#
#                TIMELINE
# ...

# %%
order_details = pd.read_table(filepath_or_buffer = "data.tsv.txt")
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Perform Initial Analysis

# %%
# Function contains --> ()
# Attribute doesn't contains  --> ()

# %%
order_details.shape
# Out:
# (4622, 5)

# %% [markdown]
# ## Terminology Alert
# * Rows - Observations/Record
# * Column - Features/Parameters

# %%
order_details.isnull()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
order_details.isnull().sum() # Chain of Functions or Chain of Commands
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.describe(include = 'all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ## Find out the items sold in the Restaurent

# %%
order_details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
print(order_details["item_name"].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# ## Give me the list of Top Selling Items

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values() # syntax for Ascending order
# Out:
# item_name
# Carnitas Salad                             1
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Bowl                                       4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Veggie Soft Tacos                          8
# Carnitas Crispy Tacos                      8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Chips and Roasted Chili-Corn Salsa        18
# Veggie Salad Bowl                         18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# ...

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending = False) # syntax for Descending order
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending = False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values(ascending = False).head(10)
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %% [markdown]
# ## Give me the list of Least Selling Items

# %%
order_details.groupby(by = "item_name")["quantity"].sum()
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values() # syntax for Ascending order
# Out:
# item_name
# Carnitas Salad                             1
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Bowl                                       4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Veggie Soft Tacos                          8
# Carnitas Crispy Tacos                      8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Chips and Roasted Chili-Corn Salsa        18
# Veggie Salad Bowl                         18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# ...

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values().head()
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Name: quantity, dtype: int64

# %%
order_details.groupby(by = "item_name")["quantity"].sum().sort_values().head(9)
# Out:
# item_name
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Crispy Tacos                         2
# Salad                                2
# Steak Salad                          4
# Bowl                                 4
# Burrito                              6
# Carnitas Salad Bowl                  6
# Name: quantity, dtype: int64

# %% [markdown]
# # Chapter - 2
# ## Data Cleaning:
# 1) Business Understanding
# 2) Data Collection
# 3) Data Understanding
# 4) Data Preparation

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details["item_price"].str.replace("$","")
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
order_details["item_price"].str.replace("$","").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
order_details["item_price"] = order_details["item_price"].str.replace("$","").astype(float)

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# # Task

# %% [markdown]
# ## Top 5 selling items individual revenue it made

# %%
order_details.groupby(["item_name","item_price"])["quantity"].sum().sort_values(ascending=False).head()
# Out:
# item_name            item_price
# Chips and Guacamole  4.45          349
# Chicken Bowl         8.75          313
# Canned Soft Drink    1.25          264
# Chicken Burrito      8.75          230
# Chicken Bowl         11.25         228
# Name: quantity, dtype: int64

# %%
 order_details["revenue"] = order_details["item_price"] * order_details["quantity"]

# %%
order_details.groupby("item_name")["revenue"].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           8044.63
# Chicken Burrito        6387.06
# Steak Burrito          4236.13
# Steak Bowl             2479.81
# Chips and Guacamole    2475.62
# Name: revenue, dtype: float64

# %%
order_details["revenue"] = order_details["item_price"] * order_details["quantity"]
order_details["revenue"].sort_values(ascending = False).head()
# Out:
# 3598    663.75
# 4152    150.00
# 1254    140.00
# 3602    140.00
# 3887    108.16
# Name: revenue, dtype: float64

# %%
top5 = order_details.groupby(by = "item_name")["revenue"].sum().sort_values(ascending=False).head(5)
top5.sum()
# Out:
# np.float64(23623.25)

# %%
order_details["order_by_individual"] = order_details["order_id"] * order_details["quantity"]

# %%
order_details.groupby("order_id")["quantity"].sum()
# Out:
# order_id
# 1       4
# 2       2
# 3       2
# 4       2
# 5       2
#        ..
# 1830    2
# 1831    3
# 1832    2
# 1833    2
# 1834    3
# Name: quantity, Length: 1834, dtype: int64

# %%
order_details.groupby("order_id")["quantity"].sum().sort_values(ascending=False).head()
# Out:
# order_id
# 1443    35
# 926     23
# 1786    20
# 1660    19
# 759     18
# Name: quantity, dtype: int64

# %%
order_details.groupby("order_id")["quantity"].sum().mode()
# Out:
# 0    2
# Name: quantity, dtype: int64

# %% [markdown]
# # Chapter - 3
# ## Pandas Data Structures
# - 1D - Series
# - 2D - Data Frame

# %%
pd.Series(data = [1,2,5.6,"$9.2"])
# Out:
# 0       1
# 1       2
# 2     5.6
# 3    $9.2
# dtype: object

# %%
pd.DataFrame(data = {
    "Name": ["Aakash", "Santhu", "Regwin", "Vignesh"],
    "Age": [23, 21, 24, 22],
    "Marks": [85, 90, 88, 92]
})
# Out:
#       Name  Age  Marks
# 0   Aakash   23     85
# 1   Santhu   21     90
# 2   Regwin   24     88
# 3  Vignesh   22     92

# %% [markdown]
# ## Task - 2
# - Create a meaningful Series
# - Create a meaningful dataset using pandas DataFrame with Dict 5 observation across 6 features

# %%
pd.Series(
    data = [85, 78, 92, 88],
    index=["Maths", "Science", "English", "Computer"]
)
# Out:
# Maths       85
# Science     78
# English     92
# Computer    88
# dtype: int64

# %%
pd.DataFrame(data = {
    "Roll no":[101,102,103,104],
    "Name": ["Aakash", "Santhu", "Regwin", "Vignesh"],
    "Age": [23, 21, 24, 22],
    "Department":["CSE","EEE","ECE","MECH"],
    "Marks": [85, 90, 88, 92],
    "Grade":["A","A+","A","A+"]
})
# Out:
#    Roll no     Name  Age Department  Marks Grade
# 0      101   Aakash   23        CSE     85     A
# 1      102   Santhu   21        EEE     90    A+
# 2      103   Regwin   24        ECE     88     A
# 3      104  Vignesh   22       MECH     92    A+

# %% [markdown]
# # Chapter - 4
# ## Filtering & Selection & Sorting

# %%
euro_2012_data = pd.read_csv("Euro_2012_stats_TEAM.csv")

# %%
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('display.max_columns',None) # to display all the columns in dataset. this step is not preffered.

# %%
euro_2012_data
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
filtered_euro_data = euro_2012_data[["Team","Goals","Red Cards","Yellow Cards"]]

# %%
filtered_euro_data
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 0               Croatia      4          0             9
# 1        Czech Republic      4          0             7
# 2               Denmark      4          0             4
# 3               England      5          0             5
# 4                France      3          0             6
# 5               Germany     10          0             4
# 6                Greece      5          1             9
# 7                 Italy      6          0            16
# 8           Netherlands      2          0             5
# 9                Poland      2          1             7
# 10             Portugal      6          0            12
# 11  Republic of Ireland      1          1             6
# 12               Russia      5          0             6
# 13                Spain     12          0            11
# 14               Sweden      5          0             7
# 15              Ukraine      2          0             5

# %%
filtered_euro_data["Yellow Cards"]
# Out:
# 0      9
# 1      7
# 2      4
# 3      5
# 4      6
# 5      4
# 6      9
# 7     16
# 8      5
# 9      7
# 10    12
# 11     6
# 12     6
# 13    11
# 14     7
# 15     5
# Name: Yellow Cards, dtype: int64

# %%
filtered_euro_data.sort_values(by = "Yellow Cards",ascending = False)
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 7                 Italy      6          0            16
# 10             Portugal      6          0            12
# 13                Spain     12          0            11
# 0               Croatia      4          0             9
# 6                Greece      5          1             9
# 14               Sweden      5          0             7
# 9                Poland      2          1             7
# 1        Czech Republic      4          0             7
# 12               Russia      5          0             6
# 11  Republic of Ireland      1          1             6
# 4                France      3          0             6
# 3               England      5          0             5
# 8           Netherlands      2          0             5
# 15              Ukraine      2          0             5
# 5               Germany     10          0             4
# 2               Denmark      4          0             4

# %% [markdown]
# ## Top 5 Yellow Cards Team

# %%
filtered_euro_data.sort_values(by = "Yellow Cards",ascending = False).head()
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11
# 0    Croatia      4          0             9
# 6     Greece      5          1             9

# %% [markdown]
# ## List the teams which has got Red Cards

# %%
filtered_euro_data["Red Cards"] == 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
filtered_euro_data[filtered_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Red Cards  Yellow Cards
# 6                Greece      5          1             9
# 9                Poland      2          1             7
# 11  Republic of Ireland      1          1             6

# %% [markdown]
# ## List the teams which has got more than 8 Yellow Cards

# %%
filtered_euro_data[filtered_euro_data["Yellow Cards"] >= 8]
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 0    Croatia      4          0             9
# 6     Greece      5          1             9
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11

# %% [markdown]
# # Task - 3
# 1) Find Out 5 New Questions along with Script Answers

# %%
filtered_euro_data.groupby(by = "Team")["Goals"].sum().sort_values(ascending = False).head()
# Out:
# Team
# Spain       12
# Germany     10
# Portugal     6
# Italy        6
# Sweden       5
# Name: Goals, dtype: int64

# %%
filtered_euro_data[filtered_euro_data["Goals"] > 5]
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 5    Germany     10          0             4
# 7      Italy      6          0            16
# 10  Portugal      6          0            12
# 13     Spain     12          0            11

# %%
filtered_euro_data.sort_values(by = "Goals",ascending = False).head()
# Out:
#         Team  Goals  Red Cards  Yellow Cards
# 13     Spain     12          0            11
# 5    Germany     10          0             4
# 10  Portugal      6          0            12
# 7      Italy      6          0            16
# 14    Sweden      5          0             7

# %%
filtered_euro_data2 = euro_2012_data[["Team","Goals","Penalty goals","Penalties not scored"]]

# %%
filtered_euro_data2
# Out:
#                    Team  Goals  Penalty goals  Penalties not scored
# 0               Croatia      4              0                     0
# 1        Czech Republic      4              0                     0
# 2               Denmark      4              0                     0
# 3               England      5              0                     0
# 4                France      3              0                     0
# 5               Germany     10              1                     0
# 6                Greece      5              1                     1
# 7                 Italy      6              0                     0
# 8           Netherlands      2              0                     0
# 9                Poland      2              0                     0
# 10             Portugal      6              0                     0
# 11  Republic of Ireland      1              0                     0
# 12               Russia      5              0                     0
# ...

# %%
filtered_euro_data2.sort_values(by = "Penalty goals", ascending = False).head()
# Out:
#        Team  Goals  Penalty goals  Penalties not scored
# 6    Greece      5              1                     1
# 5   Germany     10              1                     0
# 13    Spain     12              1                     0
# 0   Croatia      4              0                     0
# 3   England      5              0                     0

# %%
filtered_euro_data3 = euro_2012_data[["Team","Goals","Shooting Accuracy","Passing Accuracy"]]

# %%
filtered_euro_data3
# Out:
#                    Team  Goals Shooting Accuracy Passing Accuracy
# 0               Croatia      4             51.9%            76.9%
# 1        Czech Republic      4             41.9%            78.1%
# 2               Denmark      4             50.0%            83.3%
# 3               England      5             50.0%            80.6%
# 4                France      3             37.9%            87.2%
# 5               Germany     10             47.8%            87.4%
# 6                Greece      5             30.7%            76.7%
# 7                 Italy      6             43.0%            83.9%
# 8           Netherlands      2             25.0%            88.7%
# 9                Poland      2             39.4%            80.4%
# 10             Portugal      6             34.3%            77.2%
# 11  Republic of Ireland      1             36.8%            71.2%
# 12               Russia      5             22.5%            83.9%
# ...

# %%
filtered_euro_data3.sort_values(by="Shooting Accuracy", ascending=False).head()
# Out:
#        Team  Goals Shooting Accuracy Passing Accuracy
# 13    Spain     12             55.9%            88.4%
# 0   Croatia      4             51.9%            76.9%
# 2   Denmark      4             50.0%            83.3%
# 3   England      5             50.0%            80.6%
# 5   Germany     10             47.8%            87.4%

# %%
filtered_euro_data3 = euro_2012_data[["Team","Goals","Shooting Accuracy","Passing Accuracy"]].copy()

# %%
filtered_euro_data3["Passing Accuracy"] = filtered_euro_data3["Passing Accuracy"].str.replace("%","").astype(float)

# %%
filtered_euro_data3["Passing Accuracy"]
# Out:
# 0     76.9
# 1     78.1
# 2     83.3
# 3     80.6
# 4     87.2
# 5     87.4
# 6     76.7
# 7     83.9
# 8     88.7
# 9     80.4
# 10    77.2
# 11    71.2
# 12    83.9
# 13    88.4
# 14    80.9
# 15    81.7
# Name: Passing Accuracy, dtype: float64

# %%
filtered_euro_data3.sort_values(by="Passing Accuracy", ascending=False).head()
# Out:
#            Team  Goals Shooting Accuracy  Passing Accuracy
# 8   Netherlands      2             25.0%              88.7
# 13        Spain     12             55.9%              88.4
# 5       Germany     10             47.8%              87.4
# 4        France      3             37.9%              87.2
# 7         Italy      6             43.0%              83.9

# %% [markdown]
# # Chapter - 5
# ## How to Deal with Missing Values

# %%
proitbridge_emp_data = pd.read_csv("employee_data.csv")

# %%
proitbridge_emp_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# ## Data Cleaning: Level 1

# %% [markdown]
# ### Always Recomended: I'll call to my client and check with him if he can give the right data

# %% [markdown]
# #### Incase, client asking us to perform the data cleaning Operations

# %% [markdown]
# ### Step 1: Remove Duplicate Entries/Records

# %%
proitbridge_emp_data.drop_duplicates(inplace = True) # The complete operations will impact the Original Dataset

# %%
proitbridge_emp_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
proitbridge_emp_data.shape
# Out:
# (7, 5)

# %% [markdown]
# ### Step 2: Find out Null Entries

# %%
proitbridge_emp_data.isnull()
# Out:
#     Name    Age  Department  Salary  Join_Date
# 0  False  False       False   False      False
# 1  False  False       False    True      False
# 2  False   True       False   False      False
# 3  False  False       False   False      False
# 4  False  False       False   False      False
# 5  False  False       False   False      False
# 6   True  False       False   False      False

# %%
proitbridge_emp_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %% [markdown]
# ### Step 3: Drop the Null Entries

# %%
proitbridge_emp_data.dropna(inplace = True)

# %%
proitbridge_emp_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
proitbridge_emp_data.shape
# Out:
# (4, 5)

# %% [markdown]
# ### Step 4: Record in a Document
# - Client Gave totally 7 observations out of which 3 entries are removed because those records do not have complete information.
# ### Step 5: Get Approval
# - Send this to Client and get the approval to proceed for Model Building or Model Training.

# %%
proitbridge_emp_data.isnull().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# ## Data Cleaning: Level 2

# %%
employee_details = pd.read_excel("employee_data_updated.xlsx", sheet_name = "Employee_Data_From_Image")

# %%
employee_details
# Out:
#              Name   Age Department   Salary   Join_Date
# 0          Rajesh  29.0        Ops  60000.0  21-05-2023
# 1           Nasir  31.0    IT Tech  62000.0  12-11-2020
# 2         Mathiew   NaN    Support  58000.0  15-01-2025
# 3         Gilbert  29.0        Ops  60000.0  21-05-2021
# 4           Kevin  28.0    Support  61000.0  30-07-2024
# 5           Navin  35.0    Support  72000.0  19-08-2023
# 6             NaN  40.0    IT Tech  64000.0  10-09-2022
# 7          Roshan  31.0    IT Tech      NaN  12-11-2020
# 8       Kuppusamy  28.0        Ops      NaN  21-05-2021
# 9           Ajesh  28.0    Support      NaN  30-07-2024
# 10           Diya  31.0    IT Tech  63000.0  12-11-2020
# 11        Mathiew   NaN    Support  58000.0  15-01-2025
# 12  Jagadheeswari  28.0    IT Tech      NaN         NaN
# 13           Mani  28.0        Ops      NaN  21-05-2021

# %%
employee_details.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# dtype: bool

# %%
employee_details.drop_duplicates(inplace = True)

# %%
employee_details
# Out:
#              Name   Age Department   Salary   Join_Date
# 0          Rajesh  29.0        Ops  60000.0  21-05-2023
# 1           Nasir  31.0    IT Tech  62000.0  12-11-2020
# 2         Mathiew   NaN    Support  58000.0  15-01-2025
# 3         Gilbert  29.0        Ops  60000.0  21-05-2021
# 4           Kevin  28.0    Support  61000.0  30-07-2024
# 5           Navin  35.0    Support  72000.0  19-08-2023
# 6             NaN  40.0    IT Tech  64000.0  10-09-2022
# 7          Roshan  31.0    IT Tech      NaN  12-11-2020
# 8       Kuppusamy  28.0        Ops      NaN  21-05-2021
# 9           Ajesh  28.0    Support      NaN  30-07-2024
# 10           Diya  31.0    IT Tech  63000.0  12-11-2020
# 12  Jagadheeswari  28.0    IT Tech      NaN         NaN
# 13           Mani  28.0        Ops      NaN  21-05-2021

# %% [markdown]
# ### Step 2: Identify Null Entries

# %%
employee_details.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        5
# Join_Date     1
# dtype: int64

# %% [markdown]
# ### Step 3: Go for best Imputation
# - Imputation means fill some values in missing areas

# %%
employee_details["Department"].unique()
# Out:
# array(['Ops', 'IT Tech', 'Support'], dtype=object)

# %%
employee_details[employee_details["Department"] == "IT Tech"]
# Out:
#              Name   Age Department   Salary   Join_Date
# 1           Nasir  31.0    IT Tech  62000.0  12-11-2020
# 6             NaN  40.0    IT Tech  64000.0  10-09-2022
# 7          Roshan  31.0    IT Tech      NaN  12-11-2020
# 10           Diya  31.0    IT Tech  63000.0  12-11-2020
# 12  Jagadheeswari  28.0    IT Tech      NaN         NaN

# %%
employee_details[employee_details["Department"] == "Ops"]
# Out:
#          Name   Age Department   Salary   Join_Date
# 0      Rajesh  29.0        Ops  60000.0  21-05-2023
# 3     Gilbert  29.0        Ops  60000.0  21-05-2021
# 8   Kuppusamy  28.0        Ops      NaN  21-05-2021
# 13       Mani  28.0        Ops      NaN  21-05-2021

# %%
employee_details[employee_details["Department"] == "Support"]
# Out:
#       Name   Age Department   Salary   Join_Date
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 9    Ajesh  28.0    Support      NaN  30-07-2024

# %%
(employee_details["Department"] == "Support") & (employee_details["Salary"].isnull())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 12    False
# 13    False
# dtype: bool

# %%
employee_details[(employee_details["Department"] == "Support") & (employee_details["Salary"].isnull())]
# Out:
#     Name   Age Department  Salary   Join_Date
# 9  Ajesh  28.0    Support     NaN  30-07-2024

# %% [markdown]
# ## Data Analytics Task
# 1. Impute The relevant values in the Salary Column wherever it is NaN, based on Department Filtering.
# 2. Impute Mathiew's Age as 27.

# %%
employee_details.loc[(employee_details["Department"] == "Support") & (employee_details["Salary"].isnull()),"Salary"] = 70000.0

# %%
employee_details.loc[(employee_details["Department"] == "Support") & (employee_details["Age"].isnull()),"Age"] = 27.0

# %%
employee_details[employee_details["Department"] == "Support"]
# Out:
#       Name   Age Department   Salary   Join_Date
# 2  Mathiew  27.0    Support  58000.0  15-01-2025
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 9    Ajesh  28.0    Support    70000  30-07-2024
