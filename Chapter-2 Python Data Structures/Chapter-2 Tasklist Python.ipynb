# %% [markdown]
# # Task - 1

# %% [markdown]
# ## List and functions

# %%
Stationary_Store = ["Pencil","Pen","Eraser","NoteBook","WaterColor"]
Stationary_Store
# Out:
# ['Pencil', 'Pen', 'Eraser', 'NoteBook', 'WaterColor']

# %%
type(Stationary_Store)
# Out:
# list

# %%
Stationary_Store[0] = 12
Stationary_Store
# Out:
# [12, 'Pen', 'Eraser', 'NoteBook', 'WaterColor']

# %%
Stationary_Store.append("Pencil")
Stationary_Store
# Out:
# [12, 'Pen', 'Eraser', 'NoteBook', 'WaterColor', 'Pencil']

# %%
Stationary_Store = ["Pencil","Pen","Eraser","NoteBook","WaterColor"]
Stationary_Store_2 = Stationary_Store.copy()
Stationary_Store_2
# Out:
# ['Pencil', 'Pen', 'Eraser', 'NoteBook', 'WaterColor']

# %%
Stationary_Store_3 = ["Stapler","Geometry Box"]
Stationary_Store_3.extend(Stationary_Store_2)
Stationary_Store_3
# Out:
# ['Stapler',
#  'Geometry Box',
#  'Pencil',
#  'Pen',
#  'Eraser',
#  'NoteBook',
#  'WaterColor']

# %%
Stationary_Store_3.insert(1,"Marker")
Stationary_Store_3
# Out:
# ['Stapler',
#  'Marker',
#  'Geometry Box',
#  'Pencil',
#  'Pen',
#  'Eraser',
#  'NoteBook',
#  'WaterColor']

# %%
Stationary_Store_3.remove("Stapler")
Stationary_Store_3
# Out:
# ['Marker', 'Geometry Box', 'Pencil', 'Pen', 'Eraser', 'NoteBook', 'WaterColor']

# %%
Stationary_Store_4 = ["Exam pad","Pouch","Pencil Box"]
Stationary_Store_4.pop()
Stationary_Store_4
# Out:
# ['Exam pad', 'Pouch']

# %%
Stationary_Store_5 = ["Exam pad","Pouch","Pencil Box","Sketch Pen"]
Stationary_Store_5.reverse()
Stationary_Store_5
# Out:
# ['Sketch Pen', 'Pencil Box', 'Pouch', 'Exam pad']

# %%
Stationary_Store_5 = ["Exam pad","Pouch","Pencil Box","Sketch Pen"]
print(Stationary_Store_5.index("Pouch"))
# Out:
# 1

# %%
Stationary_Store_5 = ["Exam pad","Pouch","Pencil Box","Sketch Pen"]
Stationary_Store_5.reverse()
Stationary_Store_5
# Out:
# ['Sketch Pen', 'Pencil Box', 'Pouch', 'Exam pad']

# %%
Stationary_Store_6 = ["Sketch Pen","Exam pad","Sketch Pen","Pouch","Pencil Box","Sketch Pen"]
print(Stationary_Store_6.count("Sketch Pen"))
# Out:
# 3

# %%
Commercials = ["Office","School","Collage","Biology","Accounts"]
Commercials .sort()
Commercials
# Out:
# ['Accounts', 'Biology', 'Collage', 'Office', 'School']

# %%
numbers = [5, 2, 9, 1]
numbers.sort()
numbers
# Out:
# [1, 2, 5, 9]

# %% [markdown]
# ## Sets and Functions

# %%
subjects = {"Botany","Zoology","Physics"}
subjects.add("Chemistry") # Adds one element to the set.
subjects
# Out:
# {'Botany', 'Chemistry', 'Physics', 'Zoology'}

# %%
subjects.update(["Tamil","English","Maths"]) # Adds multiple elements.
subjects
# Out:
# {'Botany', 'Chemistry', 'English', 'Maths', 'Physics', 'Tamil', 'Zoology'}

# %%
subjects.remove("Maths")
subjects
# Out:
# {'Botany', 'Chemistry', 'English', 'Physics', 'Tamil', 'Zoology'}

# %%
subjects_1 = {"Botany","Physics"}
subjects_1.discard("Zoology") # Removes element without error if not present.
subjects_1
# Out:
# {'Botany', 'Physics'}

# %%
subjects_3 = {"Botany","Zoology","Physics"}
subjects_3.pop()
subjects_3
# Out:
# {'Botany', 'Zoology'}

# %%
subjects_4 = {"Botany","Zoology","Physics"}
subjects_5 = subjects_4.copy()
subjects_5
# Out:
# {'Botany', 'Physics', 'Zoology'}

# %%
A = {1,2,3,4}
B = {5,6,7,8}

A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A = {1,2,3,4,5}
B = {4,5,6,7,8}

A.intersection(B)
# Out:
# {4, 5}

# %%
A = {1,2,3,4}
B = {3,4,5,6}

A.difference(B)
# Out:
# {1, 2}

# %%
A = {1,2,3,4}
B = {3,4,5,6}

A.symmetric_difference(B)
# Out:
# {1, 2, 5, 6}

# %%
A = {1,2}
B = {1,2,3,4}

print(A.issubset(B))
# Out:
# True

# %%
A = {1,2,3,4}
B = {3,4,5,6}

A.issubset(B)
# Out:
# False

# %%
A = {1,2,3,4}
B = {3,4,5,6}

A.issuperset(B)
# Out:
# False

# %%
A = {1,2,3,4}
B = {1,2}

print(A.issuperset(B))
# Out:
# True

# %%
A = {1,2,3,4}
B = {3,4,5,6}

A.isdisjoint(B)
# Out:
# False

# %%
A = {1,2}
B = {3,4}

A.isdisjoint(B)
# Out:
# True

# %% [markdown]
# ## Tuples and Functions

# %%
numbers = (10, 20, 30, 20, 40)

numbers.count(20)
# Out:
# 2

# %%
numbers.index(40)
# Out:
# 3

# %%
max(numbers)
# Out:
# 40

# %%
min(numbers)
# Out:
# 10

# %%
sum(numbers)
# Out:
# 100

# %%
numbers = (5, 2, 8, 1)

print(sorted(numbers)) # Note: Result is list, not tuple.
# Out:
# [1, 2, 5, 8]

# %% [markdown]
# ## Dictionary and functions

# %%
student = {"Name": "Aakash", "Age": 23, "Marks": 85}
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Marks'])

# %%
student.values()
# Out:
# dict_values(['Aakash', 23, 85])

# %%
student.items()
# Out:
# dict_items([('Name', 'Aakash'), ('Age', 23), ('Marks', 85)])

# %%
student.get("Name")
# Out:
# 'Aakash'

# %%
student.update({"Marks": 98})
student
# Out:
# {'Name': 'Aakash', 'Age': 23, 'Marks': 98}

# %%
student.pop("Age") #Removes a key
student
# Out:
# {'Name': 'Aakash', 'Marks': 98}

# %%
student.popitem() # Removes last inserted item.
student
# Out:
# {'Name': 'Aakash'}

# %%
student.clear()
student
# Out:
# {}

# %%
student_2 = {"Name": "Aakash", "Age": 23, "Marks": 85}
new_student = student_2.copy()
new_student
# Out:
# {'Name': 'Aakash', 'Age': 23, 'Marks': 85}

# %%
student_3 = {"Name":"Aakash"}
student_3.setdefault("Roll no",2) # Gets value if key exists, otherwise adds new key.
student_3
# Out:
# {'Name': 'Aakash', 'Roll no': 2}

# %%
keys = ["Name","Age","Marks"]
new_dictonary = dict.fromkeys(keys, 0) # Creates dictionary with given keys.
new_dictonary
# Out:
# {'Name': 0, 'Age': 0, 'Marks': 0}

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Data Frames using Dictionaries

# %%
import pandas as pd

# %%
student_data = {
    "Name": ["Aakash", "Santhu", "Regwin", "Vignesh"],
    "Age": [23, 21, 24, 22],
    "Marks": [85, 90, 88, 92]
}

pd.DataFrame(student_data)
# Out:
#       Name  Age  Marks
# 0   Aakash   23     85
# 1   Santhu   21     90
# 2   Regwin   24     88
# 3  Vignesh   22     92

# %%
employee_data = {
    "Employee": ["John", "David", "Sara"],
    "Salary": [50000, 60000, 55000],
    "Department": ["IT", "HR", "Finance"]
}

pd.DataFrame(employee_data)
# Out:
#   Employee  Salary Department
# 0     John   50000         IT
# 1    David   60000         HR
# 2     Sara   55000    Finance

# %%
product_data = {
    "Product": ["Laptop", "Phone", "Tablet"],
    "Price": [70000, 30000, 25000],
    "Stock": [10, 20, 15]
}

pd.DataFrame(product_data)
# Out:
#   Product  Price  Stock
# 0  Laptop  70000     10
# 1   Phone  30000     20
# 2  Tablet  25000     15

# %%
product_data = {
    "Product": ["Laptop", "Phone", "Tablet"],
    "Price": [70000, 30000, 25000],
    "Stock": [10, 20, 15]
}

pd.DataFrame(product_data,index = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 product_data = {
#       2     "Product": ["Laptop", "Phone", "Tablet"],
#       3     "Price": [70000, 30000, 25000],
#       4     "Stock": [10, 20, 15]
#       5 }
# ----> 7 pd.DataFrame(product_data,index = 0)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...
