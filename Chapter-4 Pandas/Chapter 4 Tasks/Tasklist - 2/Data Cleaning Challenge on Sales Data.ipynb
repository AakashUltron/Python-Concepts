# %%
import pandas as pd

# %%
sales_data_2017 = pd.read_csv("Sales Transactions-2017.csv")
sales_data_2018 = pd.read_csv("Sales Transactions-2018.csv")
sales_data_2019 = pd.read_csv("Sales Transactions-2019.csv")

# %%
sales_full_data = pd.concat(objs = [sales_data_2017,sales_data_2018,sales_data_2019])
sales_full_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_dataset = pd.read_csv("new.csv")
sales_dataset
# Out:
#         Unnamed: 0        Date   Voucher               Party  \
# 0                0    1/4/2017     Sal:1    SOLANKI PLASTICS
# 1                1    1/4/2017     Sal:1    SOLANKI PLASTICS
# 2                2    1/4/2017     Sal:2  SARNESWARA TRADERS
# 3                3    1/4/2017     Sal:2  SARNESWARA TRADERS
# 4                4    1/4/2017     Sal:2  SARNESWARA TRADERS
# ...            ...         ...       ...                 ...
# 111201       19171  10/10/2019  Sal:4935           K.SRIHARI
# 111202       19172         NaN       NaN                 NaN
# 111203       19173         NaN       NaN                 NaN
# 111204       19174         NaN   Total                   NaN
# 111205       19175         NaN   Total                   NaN
#
#                   Product           Qty          Rate          Gross  \
# 0           DONA-VAI-9100             2      1,690.00       3,380.00
# 1         LITE FOAM(1200)             6      1,620.00       9,720.00
# ...

# %%
sales_dataset.isnull().sum()
# Out:
# Unnamed: 0             0
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
sales_dataset.dtypes
# Out:
# Unnamed: 0         int64
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_dataset.rename(columns={"Unnamed: 0": "serial.no"}, inplace=True)

# %%
sales_dataset
# Out:
#         serial.no        Date   Voucher               Party  \
# 0               0    1/4/2017     Sal:1    SOLANKI PLASTICS
# 1               1    1/4/2017     Sal:1    SOLANKI PLASTICS
# 2               2    1/4/2017     Sal:2  SARNESWARA TRADERS
# 3               3    1/4/2017     Sal:2  SARNESWARA TRADERS
# 4               4    1/4/2017     Sal:2  SARNESWARA TRADERS
# ...           ...         ...       ...                 ...
# 111201      19171  10/10/2019  Sal:4935           K.SRIHARI
# 111202      19172         NaN       NaN                 NaN
# 111203      19173         NaN       NaN                 NaN
# 111204      19174         NaN   Total                   NaN
# 111205      19175         NaN   Total                   NaN
#
#                   Product           Qty          Rate          Gross  \
# 0           DONA-VAI-9100             2      1,690.00       3,380.00
# 1         LITE FOAM(1200)             6      1,620.00       9,720.00
# ...

# %%
sales_dataset.drop_duplicates()
# Out:
#         serial.no        Date   Voucher               Party  \
# 0               0    1/4/2017     Sal:1    SOLANKI PLASTICS
# 1               1    1/4/2017     Sal:1    SOLANKI PLASTICS
# 2               2    1/4/2017     Sal:2  SARNESWARA TRADERS
# 3               3    1/4/2017     Sal:2  SARNESWARA TRADERS
# 4               4    1/4/2017     Sal:2  SARNESWARA TRADERS
# ...           ...         ...       ...                 ...
# 111201      19171  10/10/2019  Sal:4935           K.SRIHARI
# 111202      19172         NaN       NaN                 NaN
# 111203      19173         NaN       NaN                 NaN
# 111204      19174         NaN   Total                   NaN
# 111205      19175         NaN   Total                   NaN
#
#                   Product           Qty          Rate          Gross  \
# 0           DONA-VAI-9100             2      1,690.00       3,380.00
# 1         LITE FOAM(1200)             6      1,620.00       9,720.00
# ...

# %%
del sales_dataset["serial.no"]

# %%
sales_dataset
# Out:
#               Date   Voucher               Party            Product  \
# 0         1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1         1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2         1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3         1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4         1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202         NaN       NaN                 NaN                NaN
# 111203         NaN       NaN                 NaN                NaN
# 111204         NaN   Total                   NaN                NaN
# 111205         NaN   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_dataset
# Out:
#               Date   Voucher               Party            Product  \
# 0         1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1         1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2         1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3         1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4         1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202         NaN       NaN                 NaN                NaN
# 111203         NaN       NaN                 NaN                NaN
# 111204         NaN   Total                   NaN                NaN
# 111205         NaN   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_dataset.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
sales_dataset.describe(include = "all")
# Out:
#          Date Voucher   Party Product    Qty   Rate  Gross  Disc  \
# count   98615   98649  111166   98615  98649  98648  98648  5597
# unique    836   10044    1994     867    546   1109   2548   371
# top                      TP13            100
# freq     3053    3053   13056    3053  12528   3051   3053  3053
#
#        Voucher Amount
# count           27560
# unique           7149
# top
# freq             3053

# %%
sales_dataset["Date"] = pd.to_datetime(sales_dataset["Date"], errors="coerce")
sales_dataset["Date"] = sales_dataset["Date"].ffill()

# %%
sales_dataset
# Out:
#              Date   Voucher               Party            Product  \
# 0      2017-01-04     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 111201 2019-10-10  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10       NaN                 NaN                NaN
# 111203 2019-10-10       NaN                 NaN                NaN
# 111204 2019-10-10   Total                   NaN                NaN
# 111205 2019-10-10   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# 0                  2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_dataset["Date"] = sales_dataset["Date"].dt.strftime("%d/%m/%Y")
sales_dataset
# Out:
#               Date   Voucher               Party            Product  \
# 0       04/01/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1       04/01/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2       04/01/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3       04/01/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4       04/01/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...            ...       ...                 ...                ...
# 111201  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202  10/10/2019       NaN                 NaN                NaN
# 111203  10/10/2019       NaN                 NaN                NaN
# 111204  10/10/2019   Total                   NaN                NaN
# 111205  10/10/2019   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# ...

# %%
sales_dataset["Date"] = pd.to_datetime(sales_dataset["Date"], dayfirst=True)
sales_dataset
# Out:
#              Date   Voucher               Party            Product  \
# 0      2017-01-04     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 111201 2019-10-10  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10       NaN                 NaN                NaN
# 111203 2019-10-10       NaN                 NaN                NaN
# 111204 2019-10-10   Total                   NaN                NaN
# 111205 2019-10-10   Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# 0                  2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_dataset["Voucher"] = sales_dataset["Voucher"].str.replace("Sal:","")
sales_dataset
# Out:
#              Date  Voucher               Party            Product  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10      NaN                 NaN                NaN
# 111203 2019-10-10      NaN                 NaN                NaN
# 111204 2019-10-10  Total                   NaN                NaN
# 111205 2019-10-10  Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# 0                  2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_dataset["Voucher"] = sales_dataset["Voucher"].ffill()
sales_dataset
# Out:
#              Date  Voucher               Party            Product  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10     4935                 NaN                NaN
# 111203 2019-10-10     4935                 NaN                NaN
# 111204 2019-10-10  Total                   NaN                NaN
# 111205 2019-10-10  Total                   NaN                NaN
#
#                  Qty          Rate          Gross        Disc Voucher Amount
# 0                  2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
pd.read_csv("Sales-Transactions-Edited.csv")
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
sales_dataset["Voucher"] = pd.to_numeric(sales_dataset["Voucher"], errors="coerce")

# %%
sales_dataset["Voucher"] = sales_dataset["Voucher"].astype("Int64")

# %%
sales_dataset.dtypes
# Out:
# Date              datetime64[ns]
# Voucher                    Int64
# Party                     object
# Product                   object
# Qty                       object
# Rate                      object
# Gross                     object
# Disc                      object
# Voucher Amount            object
# dtype: object

# %%
del sales_dataset["Disc"]

# %%
sales_dataset
# Out:
#              Date  Voucher               Party            Product  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10     4935                 NaN                NaN
# 111203 2019-10-10     4935                 NaN                NaN
# 111204 2019-10-10     <NA>                 NaN                NaN
# 111205 2019-10-10     <NA>                 NaN                NaN
#
#                  Qty          Rate          Gross Voucher Amount
# 0                  2      1,690.00       3,380.00      13,100.00
# ...

# %%
del sales_dataset["Gross"]

# %%
del sales_dataset["Voucher Amount"]

# %%
sales_dataset
# Out:
#              Date  Voucher               Party            Product  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10     4935                 NaN                NaN
# 111203 2019-10-10     4935                 NaN                NaN
# 111204 2019-10-10     <NA>                 NaN                NaN
# 111205 2019-10-10     <NA>                 NaN                NaN
#
#                  Qty          Rate
# 0                  2      1,690.00
# 1                  6      1,620.00
# 2                500            23
# ...

# %%
sales_dataset["Rate"] = sales_dataset["Rate"].str.replace(",","")

# %%
sales_dataset
# Out:
#              Date  Voucher               Party            Product  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...      ...                 ...                ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK
# 111202 2019-10-10     4935                 NaN                NaN
# 111203 2019-10-10     4935                 NaN                NaN
# 111204 2019-10-10     <NA>                 NaN                NaN
# 111205 2019-10-10     <NA>                 NaN                NaN
#
#                  Qty        Rate
# 0                  2     1690.00
# 1                  6     1620.00
# 2                500          23
# 3                  6     1620.00
# ...

# %%
sales_dataset["Rate"] = pd.to_numeric(sales_dataset["Rate"], errors="coerce")

# %%
sales_dataset["Rate"].astype(float)
# Out:
# 0            1690.00
# 1            1620.00
# 2              23.00
# 3            1620.00
# 4            1690.00
#              ...
# 111201         16.00
# 111202           NaN
# 111203           NaN
# 111204     175381.65
# 111205    5519888.40
# Name: Rate, Length: 111206, dtype: float64

# %%
sales_dataset.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             Int64
# Party              object
# Product            object
# Qty                object
# Rate              float64
# dtype: object

# %%
sales_dataset["Qty"] = pd.to_numeric(sales_dataset["Qty"],errors = "coerce")

# %%
sales_dataset
# Out:
#              Date  Voucher               Party            Product    Qty  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0
# ...           ...      ...                 ...                ...    ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400.0
# 111202 2019-10-10     4935                 NaN                NaN    NaN
# 111203 2019-10-10     4935                 NaN                NaN    NaN
# 111204 2019-10-10     <NA>                 NaN                NaN    NaN
# 111205 2019-10-10     <NA>                 NaN                NaN    NaN
#
#               Rate
# 0          1690.00
# 1          1620.00
# 2            23.00
# ...

# %%
pd.read_csv("Sales-Transactions-Edited.csv").dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %%
sales_dataset["Qty"] = sales_dataset["Qty"].ffill()

# %%
sales_dataset
# Out:
#              Date  Voucher               Party            Product    Qty  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0
# ...           ...      ...                 ...                ...    ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400.0
# 111202 2019-10-10     4935                 NaN                NaN  400.0
# 111203 2019-10-10     4935                 NaN                NaN  400.0
# 111204 2019-10-10     <NA>                 NaN                NaN  400.0
# 111205 2019-10-10     <NA>                 NaN                NaN  400.0
#
#               Rate
# 0          1690.00
# 1          1620.00
# 2            23.00
# ...

# %%
sales_dataset["Rate"] = sales_dataset["Rate"].ffill()
sales_dataset
# Out:
#              Date  Voucher               Party            Product    Qty  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0
# ...           ...      ...                 ...                ...    ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400.0
# 111202 2019-10-10     4935                 NaN                NaN  400.0
# 111203 2019-10-10     4935                 NaN                NaN  400.0
# 111204 2019-10-10     <NA>                 NaN                NaN  400.0
# 111205 2019-10-10     <NA>                 NaN                NaN  400.0
#
#               Rate
# 0          1690.00
# 1          1620.00
# 2            23.00
# ...

# %%
sales_dataset.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             Int64
# Party              object
# Product            object
# Qty               float64
# Rate              float64
# dtype: object

# %%
sales_dataset["Qty"] = sales_dataset["Qty"].astype(int)
sales_dataset
# Out:
#              Date  Voucher               Party            Product  Qty  \
# 0      2017-01-04        1    SOLANKI PLASTICS      DONA-VAI-9100    2
# 1      2017-01-04        1    SOLANKI PLASTICS    LITE FOAM(1200)    6
# 2      2017-01-04        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500
# 3      2017-01-04        2  SARNESWARA TRADERS    LITE FOAM(1200)    6
# 4      2017-01-04        2  SARNESWARA TRADERS      DONA-VAI-9100    5
# ...           ...      ...                 ...                ...  ...
# 111201 2019-10-10     4935           K.SRIHARI     13*16 WHITE RK  400
# 111202 2019-10-10     4935                 NaN                NaN  400
# 111203 2019-10-10     4935                 NaN                NaN  400
# 111204 2019-10-10     <NA>                 NaN                NaN  400
# 111205 2019-10-10     <NA>                 NaN                NaN  400
#
#               Rate
# 0          1690.00
# 1          1620.00
# 2            23.00
# 3          1620.00
# ...

# %%
sales_dataset.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             Int64
# Party              object
# Product            object
# Qty                 int64
# Rate              float64
# dtype: object

# %%
sales_dataset = sales_dataset.drop_duplicates().dropna()
sales_dataset
# Out:
#              Date  Voucher               Party              Product  Qty  \
# 0      2017-01-04        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1      2017-01-04        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2      2017-01-04        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3      2017-01-04        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4      2017-01-04        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...      ...                 ...                  ...  ...
# 111197 2019-10-10     4935           K.SRIHARI         16*20(100-W)  140
# 111198 2019-10-10     4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 111199 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 111200 2019-10-10     4935           K.SRIHARI             10*12 RK  800
# 111201 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400
#
#           Rate
# 0       1690.0
# 1       1620.0
# 2         23.0
# 3       1620.0
# ...

# %%
sales_dataset.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             Int64
# Party              object
# Product            object
# Qty                 int64
# Rate              float64
# dtype: object

# %%
sales_dataset.to_csv("Cleaned_sales_dataset.csv")
